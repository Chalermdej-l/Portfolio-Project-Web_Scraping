# %% [markdown]
# # 1. Get hotel URLs per country
#
# Downloads the Booking.com sitemap index, expands the `en-us` child sitemaps, and writes `Hotel_url/url_country_<cc>.csv` (one file per country).
#
# The logic lives in [`src/sitemap.py`](../src/sitemap.py); this notebook is a thin wrapper around `src.sitemap.run()`.

# %%
from src.sitemap import run

url_df = run()

# %%
url_df.head()
